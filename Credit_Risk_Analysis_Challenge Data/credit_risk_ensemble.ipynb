# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# https://help.lendingclub.com/hc/en-us/articles/215488038-What-do-the-different-Note-statuses-mean-

columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

# %%
# Load the data
file_path = Path('../Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path, skiprows=1)[:-2]
df = df.loc[:, columns].copy()

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# Remove the `Issued` loan status
issued_mask = df['loan_status'] != 'Issued'
df = df.loc[issued_mask]

# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100


# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
df = df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %%
df_binary_encoded = pd.get_dummies(df.drop(columns=['loan_status']), columns=["home_ownership", "verification_status", "issue_d", "pymnt_plan", "initial_list_status", "next_pymnt_d", "application_type", "hardship_flag", "debt_settlement_flag"]) 
df_binary_encoded.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1    25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2    20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3    10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4    22000.0    0.1474       520.39     52000.0  18.76          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  issue_d_Mar-2019  \
# 0             0.0       8.0      0.0     1609.0  ...                 1
# 1             0.0      17.0      1.0    18368.0  ...                 1
# 2             0.0       8.0      0.0    13247.0  ...                 1
# 3             1.0      10.0      1.0    17996.0  ...                 1
# 4             1.0      14.0      0.0     9091.0  ...                 1
#
#    pymnt_plan_n  initial_list_status_f  initial_list_status_w  \
# 0             1                      0                      1
# 1             1                      0                      1
# 2             1                      0                      1
# 3             1                      0                      1
# 4             1                      0                      1
#
#    next_pymnt_d_Apr-2019  next_pymnt_d_May-2019  application_type_Individual  \
# 0                      0                      1                            1
# 1                      0                      1                            1
# 2                      0                      1                            1
# 3                      0                      1                            1
# 4                      0                      1                            1
#
#    application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# 0                           0                1                       1
# 1                           0                1                       1
# 2                           0                1                       1
# 3                           0                1                       1
# 4                           0                1                       1
#
# [5 rows x 95 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = pd.get_dummies(df.drop('loan_status', axis=1))

# Create our target
y = df['loan_status'].tolist()

# %%
# Create our features
X = df_binary_encoded

# Create our target
y = df[target]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  issue_d_Mar-2019  pymnt_plan_n  \
# count   68817.000000  ...      68817.000000       68817.0
# mean    17604.142828  ...          0.177238           1.0
# std     21835.880400  ...          0.381873           0.0
# min         0.000000  ...          0.000000           1.0
# 25%      6293.000000  ...          0.000000           1.0
# 50%     12068.000000  ...          0.000000           1.0
# 75%     21735.000000  ...          0.000000           1.0
# max    587191.000000  ...          1.000000           1.0
#
#        initial_list_status_f  initial_list_status_w  next_pymnt_d_Apr-2019  \
# count           68817.000000           68817.000000           68817.000000
# mean                0.123879               0.876121               0.383161
# std                 0.329446               0.329446               0.486161
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               1.000000               0.000000
# 50%                 0.000000               1.000000               0.000000
# 75%                 0.000000               1.000000               1.000000
# max                 1.000000               1.000000               1.000000
#
#        next_pymnt_d_May-2019  application_type_Individual  \
# count           68817.000000                 68817.000000
# mean                0.616839                     0.860340
# std                 0.486161                     0.346637
# min                 0.000000                     0.000000
# 25%                 0.000000                     1.000000
# 50%                 1.000000                     1.000000
# 75%                 1.000000                     1.000000
# max                 1.000000                     1.000000
#
#        application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# count                68817.000000          68817.0                 68817.0
# mean                     0.139660              1.0                     1.0
# std                      0.346637              0.0                     0.0
# min                      0.000000              1.0                     1.0
# 25%                      0.000000              1.0                     1.0
# 50%                      0.000000              1.0                     1.0
# 75%                      0.000000              1.0                     1.0
# max                      1.000000              1.0                     1.0
#
# [8 rows x 95 columns]

# %%
# Check the balance of our target values
y['loan_status'].value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble AdaBoost classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Print the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier onely, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
random_forest = BalancedRandomForestClassifier(n_estimators = 100)
random_forest = random_forest.fit(X_train, y_train)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = random_forest.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7907350784704448

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[   71,    33],
#        [ 1731, 15370]], dtype=int64)

# %%
# Print the imbalanced classification report

from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.04      0.68      0.90      0.07      0.78      0.60       104
#    low_risk       1.00      0.90      0.68      0.95      0.78      0.63     17101
#
# avg / total       0.99      0.90      0.68      0.94      0.78      0.63     17205

# %%
# List the features sorted in descending order by feature importance
feature_names = X.columns
sorted(zip(feature_names , random_forest.feature_importances_, feature_names), reverse=True)
# Out:
# [('verification_status_Verified',
#   0.0020720562315269388,
#   'verification_status_Verified'),
#  ('verification_status_Source Verified',
#   0.001970917060923972,
#   'verification_status_Source Verified'),
#  ('verification_status_Not Verified',
#   0.0032887938641799103,
#   'verification_status_Not Verified'),
#  ('total_rev_hi_lim', 0.01126639456450373, 'total_rev_hi_lim'),
#  ('total_rec_prncp', 0.08386677894733101, 'total_rec_prncp'),
#  ('total_rec_late_fee', 0.005606197128878033, 'total_rec_late_fee'),
#  ('total_rec_int', 0.050896318287809404, 'total_rec_int'),
#  ('total_pymnt_inv', 0.06707514003911971, 'total_pymnt_inv'),
#  ('total_pymnt', 0.06669856312904501, 'total_pymnt'),
#  ('total_il_high_credit_limit',
#   0.013517816041941952,
#   'total_il_high_credit_limit'),
#  ('total_cu_tl', 0.007237046745686067, 'total_cu_tl'),
#  ('total_bc_limit', 0.014966338093875995, 'total_bc_limit'),
#  ('total_bal_il', 0.011753362153797183, 'total_bal_il'),
#  ('total_bal_ex_mort', 0.012376043026986713, 'total_bal_ex_mort'),
#  ('total_acc', 0.011961693888025825, 'total_acc'),
#  ('tot_hi_cred_lim', 0.011646993870004544, 'tot_hi_cred_lim'),
#  ('tot_cur_bal', 0.01375319510721497, 'tot_cur_bal'),
#  ('tot_coll_amt', 0.005809257163435972, 'tot_coll_amt'),
#  ('tax_liens', 0.0, 'tax_liens'),
#  ('revol_bal', 0.015939455744150025, 'revol_bal'),
#  ('recoveries', 0.0, 'recoveries'),
#  ('pymnt_plan_n', 0.0, 'pymnt_plan_n'),
#  ('pub_rec_bankruptcies', 0.0011241389754817082, 'pub_rec_bankruptcies'),
#  ('pub_rec', 0.001873970437746673, 'pub_rec'),
#  ('policy_code', 0.0, 'policy_code'),
#  ('percent_bc_gt_75', 0.0076888236031271385, 'percent_bc_gt_75'),
#  ('pct_tl_nvr_dlq', 0.00966577976527547, 'pct_tl_nvr_dlq'),
#  ('out_prncp_inv', 0.011504992600744267, 'out_prncp_inv'),
#  ('out_prncp', 0.014684659826920663, 'out_prncp'),
#  ('open_rv_24m', 0.008284312026306046, 'open_rv_24m'),
#  ('open_rv_12m', 0.005090669348453466, 'open_rv_12m'),
#  ('open_il_24m', 0.006310076468838995, 'open_il_24m'),
#  ('open_il_12m', 0.0035552931564408114, 'open_il_12m'),
#  ('open_act_il', 0.005989127450392462, 'open_act_il'),
#  ('open_acc_6m', 0.004843030310991546, 'open_acc_6m'),
#  ('open_acc', 0.008478500947802723, 'open_acc'),
#  ('num_tl_op_past_12m', 0.007573789913328716, 'num_tl_op_past_12m'),
#  ('num_tl_90g_dpd_24m', 0.0012993695377559885, 'num_tl_90g_dpd_24m'),
#  ('num_tl_30dpd', 0.0, 'num_tl_30dpd'),
#  ('num_tl_120dpd_2m', 0.0, 'num_tl_120dpd_2m'),
#  ('num_sats', 0.009005164108730594, 'num_sats'),
#  ('num_rev_tl_bal_gt_0', 0.008308231800760655, 'num_rev_tl_bal_gt_0'),
#  ('num_rev_accts', 0.0077227840112203796, 'num_rev_accts'),
#  ('num_op_rev_tl', 0.008964054339420043, 'num_op_rev_tl'),
#  ('num_il_tl', 0.00787330091113095, 'num_il_tl'),
#  ('num_bc_tl', 0.008276382611273798, 'num_bc_tl'),
#  ('num_bc_sats', 0.007655018871495195, 'num_bc_sats'),
#  ('num_actv_rev_tl', 0.009489824060414761, 'num_actv_rev_tl'),
#  ('num_actv_bc_tl', 0.007923254642854977, 'num_actv_bc_tl'),
#  ('num_accts_ever_120_pd', 0.0029457177621681568, 'num_accts_ever_120_pd'),
#  ('next_pymnt_d_May-2019', 0.006495122861839546, 'next_pymnt_d_May-2019'),
#  ('next_pymnt_d_Apr-2019', 0.0054366306081427085, 'next_pymnt_d_Apr-2019'),
#  ('mths_since_recent_inq', 0.012544884219916294, 'mths_since_recent_inq'),
#  ('mths_since_recent_bc', 0.012219395171838994, 'mths_since_recent_bc'),
#  ('mths_since_rcnt_il', 0.012499236430426157, 'mths_since_rcnt_il'),
#  ('mort_acc', 0.005955785971172063, 'mort_acc'),
#  ('mo_sin_rcnt_tl', 0.008810698935864985, 'mo_sin_rcnt_tl'),
#  ('mo_sin_rcnt_rev_tl_op', 0.011394179839143346, 'mo_sin_rcnt_rev_tl_op'),
#  ('mo_sin_old_rev_tl_op', 0.014686818459153546, 'mo_sin_old_rev_tl_op'),
#  ('mo_sin_old_il_acct', 0.014907048789220433, 'mo_sin_old_il_acct'),
#  ('max_bal_bc', 0.014716633926403537, 'max_bal_bc'),
#  ('loan_amnt', 0.011531966985606497, 'loan_amnt'),
#  ('last_pymnt_amnt', 0.04934396036000668, 'last_pymnt_amnt'),
#  ('issue_d_Mar-2019', 0.01646672525251637, 'issue_d_Mar-2019'),
#  ('issue_d_Jan-2019', 0.01866724591958993, 'issue_d_Jan-2019'),
#  ('issue_d_Feb-2019', 0.00321799796045821, 'issue_d_Feb-2019'),
#  ('int_rate', 0.03289140378145562, 'int_rate'),
#  ('installment', 0.0172464472654774, 'installment'),
#  ('inq_last_6mths', 0.0058717669649193905, 'inq_last_6mths'),
#  ('inq_last_12m', 0.006159602958623163, 'inq_last_12m'),
#  ('inq_fi', 0.007343601084151306, 'inq_fi'),
#  ('initial_list_status_w', 0.0005216720744071163, 'initial_list_status_w'),
#  ('initial_list_status_f', 0.0020840576237488016, 'initial_list_status_f'),
#  ('il_util', 0.013336680553670007, 'il_util'),
#  ('home_ownership_RENT', 0.0019155170762982757, 'home_ownership_RENT'),
#  ('home_ownership_OWN', 0.00201236231496693, 'home_ownership_OWN'),
#  ('home_ownership_MORTGAGE', 0.0014860187431508442, 'home_ownership_MORTGAGE'),
#  ('home_ownership_ANY', 0.0002133140692492805, 'home_ownership_ANY'),
#  ('hardship_flag_N', 0.0, 'hardship_flag_N'),
#  ('dti', 0.016628517834040697, 'dti'),
#  ('delinq_amnt', 0.0, 'delinq_amnt'),
#  ('delinq_2yrs', 0.0031426746191378758, 'delinq_2yrs'),
#  ('debt_settlement_flag_N', 0.0, 'debt_settlement_flag_N'),
#  ('collections_12_mths_ex_med',
#   0.0005420020457636449,
#   'collections_12_mths_ex_med'),
#  ('collection_recovery_fee', 0.0, 'collection_recovery_fee'),
#  ('chargeoff_within_12_mths',
#   0.00022792363984945174,
#   'chargeoff_within_12_mths'),
#  ('bc_util', 0.014806715082066524, 'bc_util'),
#  ('bc_open_to_buy', 0.012663073703892198, 'bc_open_to_buy'),
#  ('avg_cur_bal', 0.01448601149267307, 'avg_cur_bal'),
#  ('application_type_Joint App',
#   0.001232681665726333,
#   'application_type_Joint App'),
#  ('application_type_Individual',
#   0.0014693872438859507,
#   'application_type_Individual'),
#  ('annual_inc', 0.016109361521966046, 'annual_inc'),
#  ('all_util', 0.011917794060513366, 'all_util'),
#  ('acc_open_past_24mths', 0.008964452311554376, 'acc_open_past_24mths'),
#  ('acc_now_delinq', 0.0, 'acc_now_delinq')]

# %%
# List the features sorted in descending order by feature importance
feature_names = sorted(zip(random_forest.feature_importances_,X.columns), reverse=True)
for feature in feature_names:
    print(f"{feature[1]}: ({feature[0]})")
# Out:
# total_rec_prncp: (0.08386677894733101)
# total_pymnt_inv: (0.06707514003911971)
# total_pymnt: (0.06669856312904501)
# total_rec_int: (0.050896318287809404)
# last_pymnt_amnt: (0.04934396036000668)
# int_rate: (0.03289140378145562)
# issue_d_Jan-2019: (0.01866724591958993)
# installment: (0.0172464472654774)
# dti: (0.016628517834040697)
# issue_d_Mar-2019: (0.01646672525251637)
# annual_inc: (0.016109361521966046)
# revol_bal: (0.015939455744150025)
# total_bc_limit: (0.014966338093875995)
# mo_sin_old_il_acct: (0.014907048789220433)
# bc_util: (0.014806715082066524)
# max_bal_bc: (0.014716633926403537)
# mo_sin_old_rev_tl_op: (0.014686818459153546)
# out_prncp: (0.014684659826920663)
# avg_cur_bal: (0.01448601149267307)
# tot_cur_bal: (0.01375319510721497)
# total_il_high_credit_limit: (0.013517816041941952)
# il_util: (0.013336680553670007)
# bc_open_to_buy: (0.012663073703892198)
# mths_since_recent_inq: (0.012544884219916294)
# mths_since_rcnt_il: (0.012499236430426157)
# total_bal_ex_mort: (0.012376043026986713)
# mths_since_recent_bc: (0.012219395171838994)
# total_acc: (0.011961693888025825)
# all_util: (0.011917794060513366)
# total_bal_il: (0.011753362153797183)
# tot_hi_cred_lim: (0.011646993870004544)
# loan_amnt: (0.011531966985606497)
# out_prncp_inv: (0.011504992600744267)
# mo_sin_rcnt_rev_tl_op: (0.011394179839143346)
# total_rev_hi_lim: (0.01126639456450373)
# pct_tl_nvr_dlq: (0.00966577976527547)
# num_actv_rev_tl: (0.009489824060414761)
# num_sats: (0.009005164108730594)
# acc_open_past_24mths: (0.008964452311554376)
# num_op_rev_tl: (0.008964054339420043)
# mo_sin_rcnt_tl: (0.008810698935864985)
# open_acc: (0.008478500947802723)
# num_rev_tl_bal_gt_0: (0.008308231800760655)
# open_rv_24m: (0.008284312026306046)
# num_bc_tl: (0.008276382611273798)
# num_actv_bc_tl: (0.007923254642854977)
# num_il_tl: (0.00787330091113095)
# num_rev_accts: (0.0077227840112203796)
# percent_bc_gt_75: (0.0076888236031271385)
# num_bc_sats: (0.007655018871495195)
# num_tl_op_past_12m: (0.007573789913328716)
# inq_fi: (0.007343601084151306)
# total_cu_tl: (0.007237046745686067)
# next_pymnt_d_May-2019: (0.006495122861839546)
# open_il_24m: (0.006310076468838995)
# inq_last_12m: (0.006159602958623163)
# open_act_il: (0.005989127450392462)
# mort_acc: (0.005955785971172063)
# inq_last_6mths: (0.0058717669649193905)
# tot_coll_amt: (0.005809257163435972)
# total_rec_late_fee: (0.005606197128878033)
# next_pymnt_d_Apr-2019: (0.0054366306081427085)
# open_rv_12m: (0.005090669348453466)
# open_acc_6m: (0.004843030310991546)
# open_il_12m: (0.0035552931564408114)
# verification_status_Not Verified: (0.0032887938641799103)
# issue_d_Feb-2019: (0.00321799796045821)
# delinq_2yrs: (0.0031426746191378758)
# num_accts_ever_120_pd: (0.0029457177621681568)
# initial_list_status_f: (0.0020840576237488016)
# verification_status_Verified: (0.0020720562315269388)
# home_ownership_OWN: (0.00201236231496693)
# verification_status_Source Verified: (0.001970917060923972)
# home_ownership_RENT: (0.0019155170762982757)
# pub_rec: (0.001873970437746673)
# home_ownership_MORTGAGE: (0.0014860187431508442)
# application_type_Individual: (0.0014693872438859507)
# num_tl_90g_dpd_24m: (0.0012993695377559885)
# application_type_Joint App: (0.001232681665726333)
# pub_rec_bankruptcies: (0.0011241389754817082)
# collections_12_mths_ex_med: (0.0005420020457636449)
# initial_list_status_w: (0.0005216720744071163)
# chargeoff_within_12_mths: (0.00022792363984945174)
# home_ownership_ANY: (0.0002133140692492805)
# tax_liens: (0.0)
# recoveries: (0.0)
# pymnt_plan_n: (0.0)
# policy_code: (0.0)
# num_tl_30dpd: (0.0)
# num_tl_120dpd_2m: (0.0)
# hardship_flag_N: (0.0)
# delinq_amnt: (0.0)
# debt_settlement_flag_N: (0.0)
# collection_recovery_fee: (0.0)
# acc_now_delinq: (0.0)

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
# Instantiate
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)

# Fit
eec.fit(X_train, y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = eec.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9178773283613644

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   93,    11],
#        [ 1000, 16101]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.09      0.89      0.94      0.16      0.92      0.84       104
#    low_risk       1.00      0.94      0.89      0.97      0.92      0.85     17101
#
# avg / total       0.99      0.94      0.89      0.96      0.92      0.85     17205
